# %% [markdown]
# # Background
#
# Networks arise everywhere in the practical world, especially in biology. Networks are prevalent in popular applications such as modeling the spread of disease, but the extent of network applications spreads far beyond popular science. Our first question asks how to computationally model a network without actually needing to render a picture of the network.
#
# # Problem
#
# A graph whose nodes have all been labeled can be represented by an adjacency list, in which each row of the list contains the two node labels corresponding to a unique edge.
#
# A directed graph (or digraph) is a graph containing directed edges, each of which has an orientation. That is, a directed edge is represented by an arrow instead of a line segment; the starting and ending nodes of an edge form its tail and head, respectively. The directed edge with tail v and head w is represented by ( v, w ) (but not by ( w, v ) ). A directed loop is a directed edge of the form ( v, v ).
#
# For a collection of strings and a positive integer **k**, the overlap graph for the strings is a directed graph $O_{k}$ in which each string is represented by a node, and string **s** is connected to string **t** with a directed edge when there is a length **k** suffix of **s** that matches a length **k** prefix of **t**, as long as **s≠t**; we demand **s≠t** to prevent directed loops in the overlap graph (although directed cycles may be present).
#
# Given: A collection of DNA strings in FASTA format having total length at most 10 kbp.
#
# Return: The adjacency list corresponding to $O_{3}$. You may return edges in any order.

# %% [markdown]
# # Solution

# %%
# Funtion needs to check if two strings have overlaping sequences
# Need to align the suffix of the 1st string to the prefix of the 2nd string 
# If the suffix and prefix match, return True, False otherwise
# Return False if the strings are the same to avoid directed loops in the overlap graph
# Variable, k, will hold the length of the prefix/suffix
def overlap_check(string1, string2, k):
    if string1 == string2:
        return False
    
    suffix = string1[-k:]
    prefix = string2[:k]
    
    if suffix == prefix:
        return True
    else:        
        return False

# %%
# Stress Check
s1 = 'AAATTTT'
s2='AAATCCC'

s3 = 'AAATAAA'
s4 = 'AAATTTT'
k = 3

print(overlap_check(s1,s2,k))
print(overlap_check(s3,s4,k))
# Out:
# False
# True

# %%
# BioPython package is used to parse the FASTA file
from Bio import SeqIO

filename = 'input_files/rosalind_grph.txt'
adjacency_list = []
k = 3

with open (filename,'r') as f:
    records = SeqIO.parse(f, 'fasta')
    
    # Store all seqeunces in a dictionary mapping to their respective ID
    sequence_ditctionary = {} 
    for record in records:
        sequence_ditctionary[record.id] = str(record.seq)
        
    # Want to go through each sequence and see if its suffix overlaps with the 
    # other sequences' prefix
    # If they do overlap, create a tuple of the two IDs and add them to the adjacency list 
    for ID1, seq1 in sequence_ditctionary.items():
        for ID2, seq2 in sequence_ditctionary.items():
            if overlap_check(seq1, seq2, k):
                edge_tup = (ID1,ID2)
                adjacency_list.append(edge_tup)

# %%
with open('output_files/overlap_graph.txt', 'a') as f:
    for tup in adjacency_list:
        f.write(f'{tup[0]} {tup[1]} \n')

# %%
with open('output_files/overlap_graph.txt', 'r') as f:
    content = f.read()
    print(content)
# Out:
# Rosalind_7067 Rosalind_3715
# Rosalind_7067 Rosalind_2801
# Rosalind_6107 Rosalind_6086
# Rosalind_3222 Rosalind_1542
# Rosalind_3583 Rosalind_6107
# Rosalind_3583 Rosalind_8581
# Rosalind_3583 Rosalind_7303
# Rosalind_0208 Rosalind_4604
# Rosalind_3814 Rosalind_5155
# Rosalind_3814 Rosalind_2895
# Rosalind_0549 Rosalind_6107
# Rosalind_0549 Rosalind_3583
# Rosalind_0549 Rosalind_8581
# Rosalind_0549 Rosalind_7303
# Rosalind_6673 Rosalind_0644
# Rosalind_1624 Rosalind_6483
# Rosalind_1624 Rosalind_0385
# Rosalind_3715 Rosalind_7303
# Rosalind_5175 Rosalind_1529
# Rosalind_5175 Rosalind_5059
# Rosalind_5175 Rosalind_1371
# Rosalind_5175 Rosalind_4994
# Rosalind_5175 Rosalind_0337
# Rosalind_5175 Rosalind_7323
# Rosalind_7056 Rosalind_2129
# Rosalind_7056 Rosalind_7887
# Rosalind_0644 Rosalind_6107
# Rosalind_0644 Rosalind_3583
# Rosalind_0644 Rosalind_8581
# Rosalind_0644 Rosalind_7303
# Rosalind_6089 Rosalind_5748
# Rosalind_6089 Rosalind_7803
# Rosalind_6089 Rosalind_9432
# Rosalind_7520 Rosalind_7470
# Rosalind_8381 Rosalind_7470
# Rosalind_5560 Rosalind_4644
# Rosalind_5560 Rosalind_1726
# Rosalind_5560 Rosalind_3534
# Rosalind_5560 Rosalind_3435
# Rosalind_6528 Rosalind_7406
# Rosalind_6528 Rosalind_9844
# Rosalind_6483 Rosalind_4885
# Rosalind_8010 Rosalind_0781
# Rosalind_8010 Rosalind_8381
# Rosalind_8010 Rosalind_1177
# Rosalind_6361 Rosalind_3715
# Rosalind_6361 Rosalind_2801
# Rosalind_8993 Rosalind_3636
# Rosalind_8993 Rosalind_5996
# Rosalind_5939 Rosalind_9426
# Rosalind_5939 Rosalind_7182
# Rosalind_3473 Rosalind_6528
# Rosalind_0385 Rosalind_1413
# Rosalind_3435 Rosalind_5155
# Rosalind_3435 Rosalind_2895
# Rosalind_2317 Rosalind_0649
# Rosalind_2233 Rosalind_6528
# Rosalind_4885 Rosalind_6001
# Rosalind_1177 Rosalind_5748
# Rosalind_1177 Rosalind_7803
# Rosalind_1177 Rosalind_9432
# Rosalind_0664 Rosalind_7988
# Rosalind_7887 Rosalind_1413
# Rosalind_7550 Rosalind_0235
# Rosalind_7323 Rosalind_9397
# Rosalind_1045 Rosalind_1542
# Rosalind_2801 Rosalind_6086
# Rosalind_9397 Rosalind_7067
# Rosalind_9397 Rosalind_7778
# Rosalind_9397 Rosalind_8993

# %% [markdown]
# The adjacency list shows us all the unique edges between two nodes. However, we can build a graph from the adjacency list which is easier to see the relationship bewteen nodes. The graph is represented as a dictionary where each node is mapped to a list of its corresponding neighbors.

# %%
# Next Step: Construct the graph as a map

def list_to_uni_graph(edges_array):
    graph = {}

    # Loop through the adjacency list
    for edges in edges_array:
        # If the first node of the adjacency pair does not exist in the graph, 
        # create a key for it
        if edges[0] not in graph:
            # First map the first node to the 2nd node
            graph[edges[0]] = ([edges[1]])
            # Next map the second node to the first node
            if edges[1] not in graph:
                graph[edges[1]] = ([edges[0]])
            else:
                graph[edges[1]].append(edges[0])
        
        # If the first node of the adjacency pair already exists in the graph, add it to its list of neighbors
        else:
             # First map the first node to the 2nd node
            graph[edges[0]].append(edges[1])
            # Next map the second node to the first node
            if edges[1] not in graph:
                graph[edges[1]] = ([edges[0]])
            else:
                graph[edges[1]].append(edges[0])
                   
    return graph

# %%
my_graph = list_to_uni_graph(adjacency_list)
my_graph
# Out:
# {'Rosalind_7067': ['Rosalind_3715', 'Rosalind_2801', 'Rosalind_9397'],
#  'Rosalind_3715': ['Rosalind_7067',
#   'Rosalind_3165',
#   'Rosalind_0417',
#   'Rosalind_6107',
#   'Rosalind_3583',
#   'Rosalind_8581',
#   'Rosalind_5175'],
#  'Rosalind_7323': ['Rosalind_9426',
#   'Rosalind_2601',
#   'Rosalind_5175',
#   'Rosalind_9397'],
#  'Rosalind_2601': ['Rosalind_1529',
#   'Rosalind_5059',
#   'Rosalind_1371',
#   'Rosalind_4994',
#   'Rosalind_0337',
#   'Rosalind_7323'],
#  'Rosalind_4644': ['Rosalind_8581', 'Rosalind_5560'],
#  'Rosalind_3534': ['Rosalind_8581', 'Rosalind_5560'],
#  'Rosalind_3435': ['Rosalind_8581',
#   'Rosalind_5560',
#   'Rosalind_5155',
#   'Rosalind_2895'],
#  'Rosalind_0417': ['Rosalind_3715', 'Rosalind_2801'],
#  'Rosalind_2449': ['Rosalind_1749', 'Rosalind_5956'],
#  'Rosalind_1413': ['Rosalind_7182', 'Rosalind_0385', 'Rosalind_7887'],
#  'Rosalind_7778': ['Rosalind_3222', 'Rosalind_6089', 'Rosalind_9397'],
#  'Rosalind_9432': ['Rosalind_6080',
#   'Rosalind_9671',
#   'Rosalind_6528',
#   'Rosalind_2129',
#   'Rosalind_6089',
#   'Rosalind_1177'],
#  'Rosalind_7988': ['Rosalind_4994', 'Rosalind_0664'],
#  'Rosalind_7056': ['Rosalind_7406', 'Rosalind_2129', 'Rosalind_7887'],
#  'Rosalind_4713': ['Rosalind_5058'],
#  'Rosalind_6763': ['Rosalind_0208'],
#  'Rosalind_0781': ['Rosalind_0649', 'Rosalind_8010'],
#  'Rosalind_0649': ['Rosalind_0781', 'Rosalind_2317'],
#  'Rosalind_7116': ['Rosalind_3814', 'Rosalind_1472', 'Rosalind_1045'],
#  'Rosalind_1472': ['Rosalind_7116'],
#  'Rosalind_1045': ['Rosalind_7116', 'Rosalind_1542'],
#  'Rosalind_2913': ['Rosalind_4604'],
#  'Rosalind_1538': ['Rosalind_9844'],
#  'Rosalind_6308': ['Rosalind_9844'],
#  'Rosalind_2129': ['Rosalind_5748',
#   'Rosalind_7803',
#   'Rosalind_9432',
#   'Rosalind_7056'],
#  'Rosalind_5175': ['Rosalind_1529',
#   'Rosalind_5059',
#   'Rosalind_1371',
#   'Rosalind_4994',
#   'Rosalind_0337',
#   'Rosalind_7323'],
#  'Rosalind_7887': ['Rosalind_7056', 'Rosalind_1413'],
#  'Rosalind_8381': ['Rosalind_7470', 'Rosalind_8010'],
#  'Rosalind_5560': ['Rosalind_4644',
#   'Rosalind_1726',
#   'Rosalind_3534',
#   'Rosalind_3435'],
#  'Rosalind_8010': ['Rosalind_0781', 'Rosalind_8381', 'Rosalind_1177'],
#  'Rosalind_1177': ['Rosalind_8010',
#   'Rosalind_5748',
#   'Rosalind_7803',
#   'Rosalind_9432'],
#  'Rosalind_6361': ['Rosalind_3715', 'Rosalind_2801'],
#  'Rosalind_8993': ['Rosalind_3636', 'Rosalind_5996', 'Rosalind_9397'],
#  'Rosalind_3636': ['Rosalind_8993'],
#  'Rosalind_5996': ['Rosalind_8993'],
#  'Rosalind_5939': ['Rosalind_9426', 'Rosalind_7182'],
#  'Rosalind_3473': ['Rosalind_6528'],
#  'Rosalind_2233': ['Rosalind_6528'],
#  'Rosalind_6001': ['Rosalind_4885'],
#  'Rosalind_9397': ['Rosalind_7323',
#   'Rosalind_7067',
#   'Rosalind_7778',
#   'Rosalind_8993']}
